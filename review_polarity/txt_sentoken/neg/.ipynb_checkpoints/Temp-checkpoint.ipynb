# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import glob

# %%
temp=pd.read_csv('cv000_29416.txt',index_col=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-69901615c9f5> in <module>()
# ----> 1 temp=pd.read_csv('cv000_29416.txt',index_col=False)
#
# ...

# %%
temp=pd.read_table('cv000_29416.txt', header=None)

# %%
temp
# Out:
#                                                     0
# 0   plot : two teen couples go to a church party ,...
# 1                        they get into an accident .
# 2   one of the guys dies , but his girlfriend cont...
# 3                                  what's the deal ?
# 4       watch the movie and " sorta " find out . . .
# 5   critique : a mind-fuck movie for the teen gene...
# 6   which is what makes this review an even harder...
# 7   they seem to have taken this pretty neat conce...
# 8          so what are the problems with the movie ?
# 9   well , its main problem is that it's simply to...
# 10  it starts off " normal " but then downshifts i...
# 11  there are dreams , there are characters coming...
# 12  now i personally don't mind trying to unravel ...
# 13  it's obviously got this big secret to hide , b...
# 14  and do they make things entertaining , thrilli...
# 15                                      not really .
# ...

# %%
list_=[]
for r in temp[0]:
    list_.append(r)

# %%
list
# Out:
# ['plot : two teen couples go to a church party , drink and then drive . ',
#  'they get into an accident . ',
#  'one of the guys dies , but his girlfriend continues to see him in her life , and has nightmares . ',
#  "what's the deal ? ",
#  'watch the movie and " sorta " find out . . . ',
#  'critique : a mind-fuck movie for the teen generation that touches on a very cool idea , but presents it in a very bad package . ',
#  "which is what makes this review an even harder one to write , since i generally applaud films which attempt to break the mold , mess with your head and such ( lost highway & memento ) , but there are good and bad ways of making all types of films , and these folks just didn't snag this one correctly . ",
#  'they seem to have taken this pretty neat concept , but executed it terribly . ',
#  'so what are the problems with the movie ? ',
#  "well , its main problem is that it's simply too jumbled . ",
# ...

# %%
temp.groupby('value')['0'].apply(' '.join).reset_index()

# %%
temp_arr.str.cat(sep='')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-d927fa46ee16> in <module>()
# ----> 1 temp_arr.str.cat(sep='')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'str'

# %%
temp1=pd.read_fwf('cv000_29416.txt', header=None, sep=None)

# %%
temp1
# Out:
#                                                     0              1  \
# 0   plot : two teen couples go to a church party ,...            NaN
# 1                         they get into an accident .            NaN
# 2   one of the guys dies , but his girlfriend cont...            NaN
# 3                                   what's the deal ?            NaN
# 4        watch the movie and " sorta " find out . . .            NaN
# 5   critique : a mind-fuck movie for the teen gene...            NaN
# 6   which is what makes this review an even harder...  snag this one
# 7   they seem to have taken this pretty neat conce...            NaN
# 8           so what are the problems with the movie ?            NaN
# 9   well , its main problem is that it's simply to...            NaN
# 10  it starts off " normal " but then downshifts i...            NaN
# 11  there are dreams , there are characters coming...  not explained
# 12  now i personally don't mind trying to unravel ...            NaN
# ...
